# %%
import torch
from sentence_transformers import SentenceTransformer
from transformers import AutoTokenizer, AutoModelForMaskedLM, pipeline, AutoModel

from sklearn.metrics.pairwise import cosine_similarity

from datasets import load_dataset
import math
import json

import numpy as np
from deep_translator import GoogleTranslator

import nltk
from nltk.corpus import stopwords

# %%
def read_txt(file_path):
    prompts = {}
    current_key = None

    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            line = line.strip()
            
            if not line:  # Skip empty lines
                continue

            if line.startswith('topic_'):
                current_key = line[6:]
                prompts[current_key] = []
            elif current_key:
                prompts[current_key].append(line)

    return prompts

# %%
questions_path = '../embedding/testQuestions.txt'
contexts_path = '../embedding/contexts.txt'
embContexts_path = '../embedding/embContexts.txt'

#load test_prompts, contexts, and enlarged_contexts_for_classification
prompts = read_txt(questions_path)
contexts = read_txt(contexts_path)
contextsEmb = read_txt(embContexts_path)

# %%
# model_name = "ufal/robeczech-base" 
# tokenizer = AutoTokenizer.from_pretrained(model_name)
# model = AutoModelForMaskedLM.from_pretrained(model_name)
# tokenizer = AutoTokenizer.from_pretrained('DeepPavlov/bert-base-bg-cs-pl-ru-cased')
# model = AutoModel.from_pretrained('DeepPavlov/bert-base-bg-cs-pl-ru-cased')

# %%
#pick a right model

tokenizer = AutoTokenizer.from_pretrained('sentence-transformers/all-MiniLM-L6-v2')
model = AutoModel.from_pretrained('sentence-transformers/all-MiniLM-L6-v2')
feature_extraction_pipeline = pipeline('feature-extraction', model=model, tokenizer=tokenizer)

# %%
#preprocessing czech text

# json_file_path = "/home/martin/Coding/DAS-political-confesions/embedding/stopwords-cs.json"

# with open(json_file_path, "r", encoding="utf-8") as file:
#     stopwords = json.load(file)
    
# special_characters_mapping = {'š': 's', 'č': 'c', 'ě': 'e', 'ž': 'z', 'ř': 'r', 'ý': 'y', 'á': 'a', 'í': 'i', 'é': 'e', 'ň': 'n'}
# special_characters_mapping.update({char.upper(): replacement.upper() for char, replacement in special_characters_mapping.items()})

# def preprocess_text_cs(text, stopwords):
    
#     for special_char, replacement in special_characters_mapping.items():
#         text = text.replace(special_char, replacement)
    
#     words = text.split()

#     words = [word[0:5] for word in words if len(word) > 7]
    
#     filtered_words = [word for word in words if word.lower() not in stopwords]
#     return ' '.join(filtered_words)
# Out:
# [nltk_data] Downloading package stopwords to /home/martin/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#class to process prompts
class PromptProcessor:
    def __init__(self, pipeline = feature_extraction_pipeline, source_lang='cs', target_lang='en', chunk_size=200):
        self.pipeline = feature_extraction_pipeline
        self.translator = GoogleTranslator()
        self.source_lang = source_lang
        self.target_lang = target_lang
        self.chunk_size = chunk_size

        # Download the stopwords dataset
        nltk.download('stopwords')
        self.stop_words_en = set(stopwords.words('english'))

    #gets an embedding of a prompt
    def get_embedding(self, prompt):
        #split to chunks to avoid large files
        chunks = [prompt[i:i + self.chunk_size] for i in range(0, len(prompt), self.chunk_size)]
        chunk_embeddings = []

        for chunk in chunks:
            chunk_embedding = feature_extraction_pipeline(chunk)
#             print(chunk_embedding[0])
            chunk_embedding = np.mean(chunk_embedding[0], axis=0)
            chunk_embeddings.append(chunk_embedding)
        embedding = np.mean(chunk_embeddings, axis=0)
        embedding = np.array(embedding).reshape(1, -1)
        return embedding

    #calculates a class of prompt using cosine_similarity
    def _get_prompt_embedding_class(self, prompt_embedding, embeddings):
        prompt_class = None
        max_sim = -1

        for emb_name, emb_t in embeddings.items():
            sim = cosine_similarity(prompt_embedding, emb_t)
            if sim > max_sim:
                prompt_class = emb_name
                max_sim = sim

        return prompt_class

    #remove stopwords (optional)
    def preprocess_text_en(self, sentence):
        # Tokenize the sentence and remove stop words
        filtered_tokens = [word for word in sentence.split() if word.lower() not in self.stop_words_en]
        return ' '.join(filtered_tokens)
    
    #translate, preprocess, get embedding, and return class of a prompt
    def process_prompt(self, prompt, embeddings):
        translated_prompt = self.translator.translate(prompt, src=self.source_lang, dest=self.target_lang)
        preprocessed_prompt = self.preprocess_text_en(translated_prompt)
        prompt_embedding = self.get_embedding(preprocessed_prompt)
        prompt_class = self._get_prompt_embedding_class(prompt_embedding, embeddings)

        return prompt_class

# %%
prompt_processor = PromptProcessor()
# Out:
# [nltk_data] Downloading package stopwords to /home/martin/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
embeddings = {}
for key, context in contextsEmb.items():
    preprocessed_context = preprocess_text_en(context[0])
    context_embedding = prompt_processor.get_embedding(preprocessed_context)
    embeddings[key] = context_embedding

# %%
question_embeddings = {}
for key, topic in prompts.items():
    question_embeddings[key] = {}
    for prompt in topic:
        prompt_class = prompt_processor.process_prompt(prompt, embeddings)
        question_embeddings[key][prompt] = prompt_class

# %%
#results on chatGPT generated questoins, some questions have overlap
for topic, questions in question_embeddings.items():
    print(f"Topic: {topic}")
    for question, prompt_class in questions.items():
        print(f"Question: {question}")
        print(f"Class: {prompt_class}")
        print("\n")
# Out:
# Topic: ukraine
# Question: Kdy začala konflikt na Ukrajině a jaký byl jeho původ?,
# Class: ukraine
#
#
# Question: Jaký byl vliv anexe Krymu na eskalaci konfliktu?,
# Class: ukraine
#
#
# Question: Které země podporují Ukrajinu a které podporují separatisty?,
# Class: ukraine
#
#
# Question: Jaká je aktuální humanitární situace v postižených oblastech?,
# Class: israel_palestine
#
#
# Question: Jaké jsou diplomatické snahy o řešení konfliktu a mírový proces?,
# Class: israel_palestine
#
#
# Question: Jaký je vliv války na civilní obyvatelstvo v dané oblasti?,
# Class: ukraine
#
#
# Question: Které mezinárodní organizace se aktivně angažují ve snaze ukončit konflikt?,
# Class: israel_palestine
#
#
# Question: Jaké jsou následky války na ekonomiku Ukrajiny a okolních zemí?,
# Class: ukraine
#
#
# Question: Existuje nějaký plán obnovy a rekonstrukce po skončení konfliktu?,
# Class: israel_palestine
#
#
# Question: Jaký je postoj veřejnosti v různých částech světa k ukrajinskému konfliktu?,
# Class: ukraine
#
#
# Topic: palestine
# Question: Jak vznikl současný konflikt mezi Izraelem a Palestinou?,
# Class: israel_palestine
#
#
# Question: Které faktory přispěly k nedávným násilnostem a eskalaci napětí?,
# Class: israel_palestine
#
#
# Question: Jaké jsou hlavní body sporu mezi Izraelem a Palestinci?,
# Class: israel_palestine
#
#
# Question: Jaké jsou důsledky konfliktu na civilní obyvatelstvo na obou stranách?,
# Class: israel_palestine
#
#
# Question: Jaká je role mezinárodní komunity při řešení izraelsko-palestinského konfliktu?,Existuje nějaký mírový plán nebo jednání mezi stranami konfliktu?,
# Class: israel_palestine
#
#
# Question: Jaký je postoj arabských států k izraelsko-palestinskému konfliktu?,
# Class: israel_palestine
#
#
# Question: Které mezinárodní organizace monitorují situaci a poskytují humanitární pomoc?,
# Class: israel_palestine
#
#
# Question: Jak se promítá konflikt do regionální stability na Blízkém východě?,
# Class: israel_palestine
#
#
# Question: Jaký má konflikt vliv na vnímání Izraele a Palestiny ve světě?
# Class: israel_palestine
#
#
# Topic: president
# Question: Kdo jsou hlavní kandidáti v nadcházejících českých prezidentských volbách?,
# Class: president_eleciton
#
#
# Question: Jaké jsou hlavní politické témata diskutovaná během volební kampaně?,
# Class: president_eleciton
#
#
# Question: Jaké jsou klíčové výzvy, kterým bude český prezident čelit v nadcházejícím období?,
# Class: president_eleciton
#
#
# Question: Jaký je postoj veřejnosti k jednotlivým kandidátům a jejich programům?,
# Class: president_eleciton
#
#
# Question: Jaký je vliv mediálního pokrytí na průběh volební kampaně?,
# Class: slovakia_election
#
#
# Question: Jakým způsobem probíhá volební proces a jaký je očekávaný volební účast?,
# Class: president_eleciton
#
#
# Question: Které politické strany nebo hnutí podporují jednotliví kandidáti?,
# Class: president_eleciton
#
#
# Question: Jaká je role prezidenta v českém politickém systému a jaký má pravomoci?,
# Class: president_eleciton
#
#
# Question: Jaké jsou předpokládané důsledky výsledků prezidentských voleb pro politickou scénu v České republice?,
# Class: president_eleciton
#
#
# Question: je vliv prezidentských voleb na vnímání České republiky v mezinárodním kontextu?
# Class: president_eleciton
#
#
# Topic: slovakia
# Question: Kdo jsou hlavní politické strany a kandidáti ve slovenských parlamentních volbách?,
# Class: slovakia_election
#
#
# Question: Jaké jsou klíčové politické otázky, které dominují volební kampani?,
# Class: president_eleciton
#
#
# Question: Jaký je vztah mezi Slovenskem a Evropskou unií v kontextu voleb?,
# Class: slovakia_election
#
#
# Question: Jaký je postoj veřejnosti k jednotlivým politickým stranám a lídrům?,
# Class: president_eleciton
#
#
# Question: Jaký je politický systém na Slovensku a jak funguje parlamentní volba?,
# Class: slovakia_election
#
#
# Question: Které otázky týkající se ekonomiky a sociální politiky jsou ve volbách klíčové?,
# Class: debt_social
#
#
# Question: Jaká je role Slovenska v regionálním a mezinárodním kontextu, a jak ovlivňují volby tuto pozici?,
# Class: slovakia_election
#
#
# Question: Jaká je očekávaná volební účast a jaké jsou faktory, které ji mohou ovlivnit?,
# Class: president_eleciton
#
#
# Question: Jaký je postoj kandidátů k otázkám životního prostředí a udržitelnosti?,
# Class: personal
#
#
# Question: Jak by výsledek voleb mohl ovlivnit vnitřní politické a hospodářské události ve Slovenské republice?
# Class: slovakia_election
#
#
# Topic: debt_social
# Question: Jaký je současný stav české ekonomiky a jak se liší od období předchozí vlády Andreje Babiše?
# Class: debt_social
#
#
# Question: Jaké konkrétní kroky podniká premiér Petr Fiala k řešení rostoucího státního deficitu?
# Class: debt_social
#
#
# Question: Jaký vliv má rostoucí státní dluh na ekonomiku České republiky a na občany?
# Class: debt_social
#
#
# Question: Jakým způsobem se vláda snaží podporovat ekonomický růst a zlepšit životní podmínky občanů?
# Class: debt_social
#
#
# Question: Jaký je postoj opozice k ekonomickým opatřením a návrhům vlády?
# Class: debt_social
#
#
# Question: Existují konkrétní opatření na podporu malých a středních podniků v České republice?
# Class: debt_social
#
#
# Question: Jaké jsou plány vlády ohledně investic a rozvoje infrastruktury v zemi?
# Class: debt_social
#
#
# Question: Které konkrétní opatření vláda podniká k řešení rostoucí chudoby a bídy v České republice?
# Class: debt_social
#
#
# Question: Jaký je úspěch programu Milostivé léto ve snižování exekucí a finanční tíže občanů?
# Class: debt_social
#
#
# Question: Jaký je postoj vlády k sociální pomoci a podpoře pro nejvíce potřebné?
# Class: debt_social
#
#
# Question: Existuje nějaký plán na dlouhodobé řešení sociálních nerovností v zemi?
# Class: debt_social
#
#
# Question: Jaké jsou hlavní námitky opozice vůči sociálním opatřením vlády?
# Class: debt_social
#
#
# Question: Která konkrétní opatření by mohla pomoci v boji proti chudobě a nerovnostem?
# Class: debt_social
#
#
# Question: Jaký je postoj veřejnosti k sociálním opatřením a programům vlády?
# Class: debt_social
#
#
# Topic: personal
# Question: Jaký je politický a profesní profil Petra Fialy?
# Class: personal
#
#
# Question: Které politické strany a hnutí jsou součástí koalice SPOLU, kterou Petr Fiala vede?
# Class: president_eleciton
#
#
# Question: Které funkce a ministry zastával Petr Fiala v průběhu své politické kariéry?
# Class: personal
#
#
# Question: Jaké jsou klíčové politické priority a cíle Petra Fialy jako předsedy vlády České republiky?
# Class: president_eleciton
#
#
# Question: Které významné události veřejného života ovlivnily Petr Fialu a jeho politickou kariéru?
# Class: personal
#
#
# Question: Jaká je historie jeho rodiny a jaké má vazby na politické dění v minulosti?
# Class: personal
#
#
# Question: Jaký je postoj Petra Fialy k evropské integraci a členství České republiky v Evropské unii?
# Class: slovakia_election
#
#
# Question: Jaká je jeho role ve straně ODS a jaké jsou jeho vize pro budoucnost strany?
# Class: personal
#
#
# Question: Jaké rodinné prostředí ovlivnilo politickou kariéru a hodnoty Petra Fialy?
# Class: personal
#
#
# Question: Co je historie rodinného dědictví Petra Fialy, zejména s dědečkem Františkem Fialou?
# Class: personal
#
#
# Question: Vztahy s dědečkem a babičkou formovaly život Petra Fialy?
# Class: personal
#
#
# Question: Jak se Petra Fiala staví k otázkám spojeným s dědictvím během druhé světové války?
# Class: personal
#
#
# Question: Které hodnoty z rodinného prostředí ovlivnily politické postoje Petra Fialy?
# Class: personal
#
#
# Question: Klíčové momenty v osobním životě Petra Fialy před politikou a jeho vztah s manželkou Janou Fialovou.
# Class: personal
#
#
# Question: Zájmy a aktivity Petra Fialy mimo politiku a jejich vliv na jeho veřejnou práci.
# Class: personal

# %%
import pickle

# %%
with open('contexts_embeddings.pkl', 'wb') as f:
    pickle.dump(embeddings, f)

# %%
with open('contexts.pkl', 'wb') as f:
    pickle.dump(contexts, f)
