# %%
import requests
from bs4 import BeautifulSoup
import copy
import yaml
import os
import re
import pandas as pd

#function for scraping webpage demagog.cz for politicians quotes-> right now it is set to Andrej Babis
#politician = "Andrej Babiš"
URL_demagog = 'https://demagog.cz/politici/andrej-babis-183'
filename = "./data/demagog_Babis.yaml"

URL_vadne = 'https://demagog.cz/politici/andrej-babis-183?page=47'

# %%
def get_url_data(URL, politician):
    
    data = []

    page = requests.get(URL)
    if page.status_code != 200:
        raise ValueError(f"Failed to fetch the webpage. HTTP Status Code: {page.status_code}")
    html_content = page.text
    soup = BeautifulSoup(html_content, "html.parser")

    class_pattern = re.compile(r"fs-5 text-uppercase fs-600 text-(\w+)")

    
    quotes_all = soup.find_all('span', class_ = "fs-6 position-relative")
    truths_all = soup.find_all('div', class_ = "content fs-6")
    states_all = soup.find_all(attrs={"class": class_pattern})
    
    '''
    print(len(quotes_all))
    print(len(states_all))
    print(len(truths_all))
    
    for i in range(10):
        print(quotes[i].string + ", " + states[i].string + ", " + truths[i].string + "\n")
    '''

    if(len(quotes_all) != len(truths_all) != len(states_all)):
        print("Data lengths on URL: " + URL + " are not equal and do not correspond to each other.")
    
    for idx in range(len(quotes_all)):
        quote_current = quotes_all[idx].text
        quote_current = quote_current.replace('\xa0', ' ').replace('\n',' ').strip()
        #print(quote_current)

        state_current = states_all[idx].string
        state_current = state_current.strip().replace('\n',' ').strip()
        #print(state_current)
        truth_current = truths_all[idx].string
        truth_current = truth_current.replace('\xa0', ' ').replace('\n',' ').strip()
        #print(truth_current)

        data_current = {"name": politician, "quote": quote_current, "state": state_current, "truth": truth_current}
        data.append(data_current)
    
    
    return data

# %%
def url_cycle(URL, politician, filename):

    data_all = get_url_data(URL_demagog,"Andrej Babiš")
    print("The 1. URL(" + URL + ") has been scraped.")
    
    for idx in range(105):
        i = idx + 2
     
        URL_current = URL + "?page=" + str(i)
        if i == 47:
            print("skipping URL " + URL_current + ".") 
            continue
        data_current = get_url_data(URL_current, politician)
        data_all.append(data_current)
        print("The " + str(i) + ". URL(" + URL_current + ") has been scraped.") 

    with open(filename, "w", encoding="utf-8") as file:
        yaml.dump(data_all, file, default_flow_style=False, allow_unicode=True)
    
    #df = pd.DataFrame(data_all)
    #df.to_csv(filename, index=False)

    print("All data saved to file: " + filename + ". ")

    return

# %%
url_cycle(URL_demagog, "Andrej Babiš", filename)
#print(get_url_data(URL_vadne,"Andrej Babiš"))
# Out:
# The 1. URL(https://demagog.cz/politici/andrej-babis-183) has been scraped.
# The 2. URL(https://demagog.cz/politici/andrej-babis-183?page=2) has been scraped.
# The 3. URL(https://demagog.cz/politici/andrej-babis-183?page=3) has been scraped.
# The 4. URL(https://demagog.cz/politici/andrej-babis-183?page=4) has been scraped.
# The 5. URL(https://demagog.cz/politici/andrej-babis-183?page=5) has been scraped.
# The 6. URL(https://demagog.cz/politici/andrej-babis-183?page=6) has been scraped.
# The 7. URL(https://demagog.cz/politici/andrej-babis-183?page=7) has been scraped.
# The 8. URL(https://demagog.cz/politici/andrej-babis-183?page=8) has been scraped.
# The 9. URL(https://demagog.cz/politici/andrej-babis-183?page=9) has been scraped.
# The 10. URL(https://demagog.cz/politici/andrej-babis-183?page=10) has been scraped.
# The 11. URL(https://demagog.cz/politici/andrej-babis-183?page=11) has been scraped.
# The 12. URL(https://demagog.cz/politici/andrej-babis-183?page=12) has been scraped.
# The 13. URL(https://demagog.cz/politici/andrej-babis-183?page=13) has been scraped.
# The 14. URL(https://demagog.cz/politici/andrej-babis-183?page=14) has been scraped.
# The 15. URL(https://demagog.cz/politici/andrej-babis-183?page=15) has been scraped.
# The 16. URL(https://demagog.cz/politici/andrej-babis-183?page=16) has been scraped.
# The 17. URL(https://demagog.cz/politici/andrej-babis-183?page=17) has been scraped.
# The 18. URL(https://demagog.cz/politici/andrej-babis-183?page=18) has been scraped.
# The 19. URL(https://demagog.cz/politici/andrej-babis-183?page=19) has been scraped.
# The 20. URL(https://demagog.cz/politici/andrej-babis-183?page=20) has been scraped.
# The 21. URL(https://demagog.cz/politici/andrej-babis-183?page=21) has been scraped.
# The 22. URL(https://demagog.cz/politici/andrej-babis-183?page=22) has been scraped.
# The 23. URL(https://demagog.cz/politici/andrej-babis-183?page=23) has been scraped.
# The 24. URL(https://demagog.cz/politici/andrej-babis-183?page=24) has been scraped.
# The 25. URL(https://demagog.cz/politici/andrej-babis-183?page=25) has been scraped.
# The 26. URL(https://demagog.cz/politici/andrej-babis-183?page=26) has been scraped.
# The 27. URL(https://demagog.cz/politici/andrej-babis-183?page=27) has been scraped.
# The 28. URL(https://demagog.cz/politici/andrej-babis-183?page=28) has been scraped.
# The 29. URL(https://demagog.cz/politici/andrej-babis-183?page=29) has been scraped.
# The 30. URL(https://demagog.cz/politici/andrej-babis-183?page=30) has been scraped.
# The 31. URL(https://demagog.cz/politici/andrej-babis-183?page=31) has been scraped.
# The 32. URL(https://demagog.cz/politici/andrej-babis-183?page=32) has been scraped.
# The 33. URL(https://demagog.cz/politici/andrej-babis-183?page=33) has been scraped.
# The 34. URL(https://demagog.cz/politici/andrej-babis-183?page=34) has been scraped.
# The 35. URL(https://demagog.cz/politici/andrej-babis-183?page=35) has been scraped.
# The 36. URL(https://demagog.cz/politici/andrej-babis-183?page=36) has been scraped.
# The 37. URL(https://demagog.cz/politici/andrej-babis-183?page=37) has been scraped.
# The 38. URL(https://demagog.cz/politici/andrej-babis-183?page=38) has been scraped.
# The 39. URL(https://demagog.cz/politici/andrej-babis-183?page=39) has been scraped.
# The 40. URL(https://demagog.cz/politici/andrej-babis-183?page=40) has been scraped.
# The 41. URL(https://demagog.cz/politici/andrej-babis-183?page=41) has been scraped.
# The 42. URL(https://demagog.cz/politici/andrej-babis-183?page=42) has been scraped.
# The 43. URL(https://demagog.cz/politici/andrej-babis-183?page=43) has been scraped.
# The 44. URL(https://demagog.cz/politici/andrej-babis-183?page=44) has been scraped.
# The 45. URL(https://demagog.cz/politici/andrej-babis-183?page=45) has been scraped.
# The 46. URL(https://demagog.cz/politici/andrej-babis-183?page=46) has been scraped.
# skipping URL https://demagog.cz/politici/andrej-babis-183?page=47.
# Data lengths on URL: https://demagog.cz/politici/andrej-babis-183?page=48 are not equal and do not correspond to each other.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[116], line 1
# ----> 1 url_cycle(URL_demagog, "Andrej Babiš", filename)
#       2 #print(get_url_data(URL_vadne,"Andrej Babiš"))
#
# Cell In[115], line 13, in url_cycle(URL, politician, filename)
#      11     print("skipping URL " + URL_current + ".")
#      12     continue
# ---> 13 data_current = get_url_data(URL_current, politician)
#      14 data_all.append(data_current)
#      15 print("The " + str(i) + ". URL(" + URL_current + ") has been scraped.")
#
# Cell In[114], line 38, in get_url_data(URL, politician)
#      36 state_current = state_current.strip().replace('\n',' ').strip()
#      37 #print(state_current)
# ---> 38 truth_current = truths_all[idx].string
#      39 truth_current = truth_current.replace('\xa0', ' ').replace('\n',' ').strip()
#      40 #print(truth_current)
#
# IndexError: list index out of range
